# %% [markdown]
# Canva Link : https://canva.link/73v53omyay12zic

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#loading the data set
df=pd.read_csv('/content/student_depression_dataset (1).csv')

# %%
df.shape
# Out:
# (27870, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27870 entries, 0 to 27869
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27870 non-null  int64
#  1   Gender                                 27870 non-null  object
#  2   Age                                    27870 non-null  int64
#  3   City                                   27870 non-null  object
#  4   Profession                             27870 non-null  object
#  5   Academic Pressure                      27870 non-null  int64
#  6   Work Pressure                          27870 non-null  int64
#  7   CGPA                                   27870 non-null  float64
#  8   Study Satisfaction                     27870 non-null  int64
#  9   Job Satisfaction                       27870 non-null  int64
# ...

# %%
df.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27870.000000  27870.000000       27870.000000   27870.000000
# mean    70439.182634     25.821134           3.140617       0.000431
# std     40633.159539      4.906574           1.381640       0.044016
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35055.000000     21.000000           2.000000       0.000000
# 50%     70654.500000     25.000000           3.000000       0.000000
# 75%    105813.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27870.000000        27870.000000      27870.000000      27870.000000
# mean       7.656028            2.943559          0.000682          7.157948
# std        1.470835            1.361209          0.044419          3.707180
# ...

# %%
df.head(5)
# Out:
#    id  Gender  Age           City Profession  Academic Pressure  \
# 0   2    Male   33  Visakhapatnam    Student                  5
# 1   8  Female   24      Bangalore    Student                  2
# 2  26    Male   31       Srinagar    Student                  3
# 3  30  Female   28       Varanasi    Student                  3
# 4  32  Female   25         Jaipur    Student                  4
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction Sleep Duration  \
# 0              0  8.97                   2                 0              6
# 1              0  5.90                   5                 0              6
# 2              0  7.03                   5                 0              4
# 3              0  5.59                   2                 0              7
# 4              0  8.13                   3                 0              6
#
#   Dietary Habits   Degree Have you ever had suicidal thoughts ?  \
# ...

# %%
df.tail(5)
# Out:
#            id  Gender  Age       City Profession  Academic Pressure  \
# 27865  140685  Female   27      Surat    Student                  5
# 27866  140686    Male   27   Ludhiana    Student                  2
# 27867  140689    Male   31  Faridabad    Student                  3
# 27868  140690  Female   18   Ludhiana    Student                  5
# 27869  140699    Male   27      Patna    Student                  4
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 27865              0  5.75                   5                 0
# 27866              0  9.40                   3                 0
# 27867              0  6.61                   4                 0
# 27868              0  6.88                   2                 0
# 27869              0  9.24                   1                 0
#
#       Sleep Duration Dietary Habits      Degree  \
# 27865              6      Unhealthy  'Class 12'
# 27866              4        Healthy         MSc
# ...

# %%
df.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 27865    False
# 27866    False
# 27867    False
# 27868    False
# 27869    False
# Length: 27870, dtype: bool

# %%
pd.set_option('display.max_columns', None)
print(df.head())
# Out:
#    id  Gender  Age           City Profession  Academic Pressure  \
# 0   2    Male   33  Visakhapatnam    Student                  5
# 1   8  Female   24      Bangalore    Student                  2
# 2  26    Male   31       Srinagar    Student                  3
# 3  30  Female   28       Varanasi    Student                  3
# 4  32  Female   25         Jaipur    Student                  4
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction Sleep Duration  \
# 0              0  8.97                   2                 0              6
# 1              0  5.90                   5                 0              6
# 2              0  7.03                   5                 0              4
# 3              0  5.59                   2                 0              7
# 4              0  8.13                   3                 0              6
#
#   Dietary Habits   Degree Have you ever had suicidal thoughts ?  \
# ...

# %%
categorical_cols = df.select_dtypes(include='object').columns
print(categorical_cols)
# Out:
# Index(['Gender', 'City', 'Profession', 'Sleep Duration', 'Dietary Habits',
#        'Degree', 'Have you ever had suicidal thoughts ?', 'Financial Stress',
#        'Family History of Mental Illness'],
#       dtype='object')

# %%
import pandas as pd

# The 'Depression' column is already numerically encoded with values 0 and 1.
# No further categorical encoding is needed for this column.
# We can verify its unique values and data type.
print("Unique values in 'Depression' column:", df['Depression'].unique())
print("Data type of 'Depression' column:", df['Depression'].dtype)
# Out:
# Unique values in 'Depression' column: [1 0]
# Data type of 'Depression' column: int64

# %%
df = df.drop(columns=['id'])

# %%
y = df['Depression']

# %%
y = y.map({'No':0, 'Yes':1})

# %%
X = df.drop(columns=['Depression'])

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %%
from sklearn.preprocessing import OrdinalEncoder

categorical_cols = [
    'Gender',
    'City',
    'Profession',
    'Sleep Duration',
    'Dietary Habits',
    'Degree',
    'Have you ever had suicidal thoughts ?',
    'Financial Stress',
    'Family History of Mental Illness'
]

# Create a copy to avoid modifying the original DataFrame issues seen in previous steps
X = df.drop(columns=['Depression']).copy()

# Initialize OrdinalEncoder
encoder = OrdinalEncoder()

# Apply OrdinalEncoder to the specified categorical columns in X
X[categorical_cols] = encoder.fit_transform(X[categorical_cols])

print("X after Ordinal Encoding:")
print(X.head())
# Out:
# X after Ordinal Encoding:
#    Gender  Age  City  Profession  Academic Pressure  Work Pressure  CGPA  \
# 0     1.0   33  51.0         0.0                  5              0  8.97
# 1     0.0   24   5.0         0.0                  2              0  5.90
# 2     1.0   31  44.0         0.0                  3              0  7.03
# 3     0.0   28  49.0         0.0                  3              0  5.59
# 4     0.0   25  18.0         0.0                  4              0  8.13
#
#    Study Satisfaction  Job Satisfaction  Sleep Duration  Dietary Habits  \
# 0                   2                 0             1.0             0.0
# 1                   5                 0             1.0             1.0
# 2                   5                 0             0.0             0.0
# 3                   2                 0             2.0             1.0
# 4                   3                 0             1.0             1.0
#
# ...

# %%
X.shape
# Out:
# (27870, 16)

# %%
X
# Out:
#        Gender  Age  City  Profession  Academic Pressure  Work Pressure  CGPA  \
# 0         1.0   33  51.0         0.0                  5              0  8.97
# 1         0.0   24   5.0         0.0                  2              0  5.90
# 2         1.0   31  44.0         0.0                  3              0  7.03
# 3         0.0   28  49.0         0.0                  3              0  5.59
# 4         0.0   25  18.0         0.0                  4              0  8.13
# ...       ...  ...   ...         ...                ...            ...   ...
# 27865     0.0   27  45.0         0.0                  5              0  5.75
# 27866     1.0   27  25.0         0.0                  2              0  9.40
# 27867     1.0   31  11.0         0.0                  3              0  6.61
# 27868     0.0   18  25.0         0.0                  5              0  6.88
# 27869     1.0   27  38.0         0.0                  4              0  9.24
#
# ...

# %%
y = df['Depression'].map({'No': 0, 'Yes': 1})
X = X.copy()

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27870 entries, 0 to 27869
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Gender                                 27870 non-null  object
#  1   Age                                    27870 non-null  int64
#  2   City                                   27870 non-null  object
#  3   Profession                             27870 non-null  object
#  4   Academic Pressure                      27870 non-null  int64
#  5   Work Pressure                          27870 non-null  int64
#  6   CGPA                                   27870 non-null  float64
#  7   Study Satisfaction                     27870 non-null  int64
#  8   Job Satisfaction                       27870 non-null  int64
#  9   Sleep Duration                         27870 non-null  object
# ...

# %%
df['Depression'].value_counts()
# Out:
# Depression
# 1    16308
# 0    11562
# Name: count, dtype: int64

# %% [markdown]
# # ***EDA***

# %%
# %matplotlib inline

# %%
sns.boxplot(x='Age', data=df)
plt.title('Boxplot of Age')
plt.show()

# %%
q1 = df['Age'].quantile(0.25)
q3 = df['Age'].quantile(0.75)
iqr = q3 - q1
print("IQR for Age", iqr)
upperrange = q3 + 1.5 * iqr
bottomrange = q1 - 1.5 * iqr
df_clean = df[(df['Age'] > bottomrange) & (df['Age'] < upperrange)]
sns.boxplot(x='Age', data=df_clean)
plt.title('Boxplot of Age (Without Outliers)')
plt.show()
# Out:
# IQR for Age 9.0

# %%
sns.boxplot(x='Academic Pressure', data=df)
plt.title('Boxplot of Academic Pressure')
plt.show()

# %%
sns.boxplot(x='Work Pressure', data=df)
plt.title('Boxplot of Work Pressure')
plt.show()

# %%
q1 = df['Work Pressure'].quantile(0.25)
q3 = df['Work Pressure'].quantile(0.75)
iqr = q3 - q1
print("IQR for Work Pressure", iqr)
upperrange = q3 + 1.5 * iqr
bottomrange = q1 - 1.5 * iqr
df_clean = df[(df['Work Pressure'] > bottomrange) & (df['Work Pressure'] < upperrange)]
sns.boxplot(x='Work Pressure', data=df_clean)
plt.title('Boxplot of Work Pressure (Without Outliers)')
plt.show()
# Out:
# IQR for Work Pressure 0.0

# %%
sns.boxplot(x='CGPA', data=df)
plt.title('Boxplot of CGPA')
plt.show()

# %%
q1 = df['CGPA'].quantile(0.25)
q3 = df['CGPA'].quantile(0.75)
iqr = q3 - q1
print("IQR for CGPA ", iqr)
upperrange = q3 + 1.5 * iqr
bottomrange = q1 - 1.5 * iqr
df_clean = df[(df['CGPA'] > bottomrange) & (df['CGPA'] < upperrange)]
sns.boxplot(x='CGPA', data=df_clean)
plt.title('Boxplot of CGPA (Without Outliers)')
plt.show()
# Out:
# IQR for CGPA  2.63

# %%
sns.boxplot(x='Study Satisfaction', data=df)
plt.title('Boxplot of Study Satisfaction')
plt.show()

# %%
sns.boxplot(x='Job Satisfaction', data=df)
plt.title('Boxplot of Job Satisfaction')
plt.show()

# %%
q1 = df['Job Satisfaction'].quantile(0.25)
q3 = df['Job Satisfaction'].quantile(0.75)
iqr = q3 - q1
print("IQR for Job Satisfaction ", iqr)
upperrange = q3 + 1.5 * iqr
bottomrange = q1 - 1.5 * iqr
df_clean = df[(df['Job Satisfaction'] > bottomrange) & (df['Job Satisfaction'] < upperrange)]
sns.boxplot(x='Job Satisfaction', data=df_clean)
plt.title('Boxplot of Job Satisfaction (Without Outliers)')
plt.show()
# Out:
# IQR for Job Satisfaction  0.0

# %%
sns.boxplot(x='Work/Study Hours', data=df)
plt.title('Boxplot of Work/Study Hours')
plt.show()

# %%
sns.boxplot(x='Depression', data=df)
plt.title('Boxplot of Depression')
plt.show()

# %%
q3 = df['Age'].quantile(0.75)
q1 = df['Age'].quantile(0.25)
iqr = q3 - q1
print("IQR for Age:", iqr)
# Out:
# IQR for Age: 9.0

# %%
q3 = df['Academic Pressure'].quantile(0.75)
q1 = df['Academic Pressure'].quantile(0.25)
iqr = q3 - q1
print("IQR for Academic Pressure:", iqr)
# Out:
# IQR for Academic Pressure: 2.0

# %%
q3 = df['Work Pressure'].quantile(0.75)
q1 = df['Work Pressure'].quantile(0.25)
iqr = q3 - q1
print("IQR for Work Pressure:", iqr)
# Out:
# IQR for Work Pressure: 0.0

# %%
q3 = df['CGPA'].quantile(0.75)
q1 = df['CGPA'].quantile(0.25)
iqr = q3 - q1
print("IQR for CGPA:", iqr)
# Out:
# IQR for CGPA: 2.63

# %%
q3 = df['Study Satisfaction'].quantile(0.75)
q1 = df['Study Satisfaction'].quantile(0.25)
iqr = q3 - q1
print("IQR for Study Satisfaction:", iqr)
# Out:
# IQR for Study Satisfaction: 2.0

# %%
q3 = df['Job Satisfaction'].quantile(0.75)
q1 = df['Job Satisfaction'].quantile(0.25)
iqr = q3 - q1
print("IQR for Job Satisfaction:", iqr)
# Out:
# IQR for Job Satisfaction: 0.0

# %%
q3 = df['Work/Study Hours'].quantile(0.75)
q1 = df['Work/Study Hours'].quantile(0.25)
iqr = q3 - q1
print("IQR for Work/Study Hours:", iqr)
# Out:
# IQR for Work/Study Hours: 6.0

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
correlation = df.corr(numeric_only=True)['Depression'].sort_values(ascending=False)
print(correlation)
# Out:
# Depression            1.000000
# Academic Pressure     0.474805
# Work/Study Hours      0.209024
# CGPA                  0.022164
# Work Pressure        -0.003345
# Job Satisfaction     -0.003472
# Study Satisfaction   -0.168132
# Age                  -0.226738
# Name: Depression, dtype: float64

# %%
top_features = correlation[correlation > 0.3].index.tolist()
print(top_features)
# Out:
# ['Depression', 'Academic Pressure']

# %%
correlation = df.corr(numeric_only=True)['Age'].sort_values(ascending=False)
print("Correlation with Age:")
print(correlation)
# Out:
# Correlation with Age:
# Age                   1.000000
# Study Satisfaction    0.009131
# CGPA                  0.005167
# Work Pressure         0.002018
# Job Satisfaction     -0.000428
# Work/Study Hours     -0.032775
# Academic Pressure    -0.075871
# Depression           -0.226738
# Name: Age, dtype: float64

# %%
correlation = df.corr(numeric_only=True)['Age'].sort_values(ascending=False)
top_features = correlation[correlation > 0.3].index.tolist()
print("Top positively correlated features with Age:")
print(top_features)
# Out:
# Top positively correlated features with Age:
# ['Age']

# %%
#Boxplot for All Numerical Columns
df.boxplot(figsize=(25, 12))
plt.title('Boxplot for All Numerical Features')
plt.show()

# %%
#Histogram of Age
plt.hist(df['Age'], bins=20, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
plt.show()

# %%
# Histograms for All Columns
# Draw histograms for each column in the dataset

# Select only numeric columns for plotting
numeric_columns = df.select_dtypes(include=['number']).columns
num_columns = len(numeric_columns)
num_rows = (num_columns + 1) // 2  # Calculate the number of rows for subplots

fig, axes = plt.subplots(nrows=num_rows, ncols=2, figsize=(12, num_rows * 4))  # Adjust figsize based on num_rows

# Flatten axes if multiple rows are used
axes = axes.flatten()

for i, column in enumerate(numeric_columns):
    df[column].hist(ax=axes[i], bins=20)  # Adjust bins as needed
    axes[i].set_title(f"{column}")
    axes[i].set_xlabel(column)
    axes[i].set_ylabel("Frequency")

# If there's an odd number of columns, remove the empty subplot
if num_columns % 2 != 0:
    fig.delaxes(axes[num_columns])

plt.tight_layout()  # Adjust layout for spacing between subplots
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

selected_cols = [
    'Age',
    'CGPA',
    'Work/Study Hours',
    'Academic Pressure',
    'Financial Stress'
]

sns.pairplot(df[selected_cols + ['Depression']], hue='Depression')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cat_columns = [
    'Gender',
    'City',
    'Profession',
    'Sleep Duration',
    'Dietary Habits',
    'Degree',
    'Have you ever had suicidal thoughts ?',
    'Family History of Mental Illness'
]

num_cols = len(cat_columns)
num_rows = (num_cols + 1) // 2

fig, axes = plt.subplots(nrows=num_rows, ncols=2, figsize=(14, num_rows * 4))
axes = axes.flatten()

for i, col in enumerate(cat_columns):
    sns.countplot(x=col, data=df, ax=axes[i])
    axes[i].set_title(f"Count Plot for {col}")
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Count")
    axes[i].tick_params(axis='x', rotation=45)

# Remove extra empty subplot if odd number of plots
if num_cols % 2 != 0:
    fig.delaxes(axes[-1])

plt.tight_layout()
plt.show()

# %%
for col in cat_columns:
    plt.figure(figsize=(6,4))
    sns.countplot(x=col, hue='Depression', data=df)
    plt.title(f"{col} vs Depression")
    plt.xticks(rotation=45)
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x='Gender', y='Depression', data=df)
plt.title('Depression by Gender')
plt.ylabel('Mean Depression (0=No, 1=Yes)')
plt.show()

# %%
sns.barplot(x='Sleep Duration', y='Depression', data=df)
plt.title('Depression by Sleep Duration')
plt.xticks(rotation=45)
plt.ylabel('Mean Depression (0=No, 1=Yes)')
plt.show()

# %%
sns.barplot(x='Academic Pressure', y='Depression', data=df)
plt.title('Depression by Academic Pressure')
plt.ylabel('Mean Depression (0=No, 1=Yes)')
plt.show()

# %%
sns.barplot(x='Gender', y='Depression', hue='Family History of Mental Illness', data=df)
plt.title('Depression by Gender and Family History of Mental Illness')
plt.ylabel('Mean Depression (0 = No, 1 = Yes)')
plt.show()

# %%
sns.barplot(x='Sleep Duration', y='Depression',hue='Have you ever had suicidal thoughts ?', data=df)
plt.title('Depression by Sleep Duration and Suicidal Thoughts')
plt.xticks(rotation=45)
plt.ylabel('Mean Depression (0 = No, 1 = Yes)')
plt.show()

# %%
sns.barplot(x='Profession', y='Depression', hue='Gender', data=df)
plt.title('Depression by Profession and Gender')
plt.xticks(rotation=45)
plt.ylabel('Mean Depression (0 = No, 1 = Yes)')
plt.show()

# %%
gender_counts = df['Gender'].value_counts()
labels = gender_counts.index

plt.figure(figsize=(6,6))
plt.pie(gender_counts, labels=labels, autopct='%1.1f%%')
plt.title('Gender Distribution')
plt.show()

# %%
dep_gender = pd.crosstab(df['Gender'], df['Depression'])

dep_gender.plot(kind='pie', subplots=True, autopct='%1.1f%%', figsize=(10,5))
plt.suptitle('Gender Distribution by Depression Status')
plt.show()

# %%
numeric_cols = df.select_dtypes(include=['number']).columns
sns.pairplot(df[numeric_cols], hue='Depression')
plt.suptitle('Scatter Plots of Numerical Columns by Depression Status', y=1.02)
plt.show()

# %%
# Define features and target
features = X.columns
target = 'Depression'

# Number of columns for subplot layout
num_cols = 3
num_features = len(features)
num_rows = -(-num_features // num_cols)  # ceiling division

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, num_rows*4))
axes = axes.flatten()

# Plot scatter plots of each feature vs target
for i, feature in enumerate(features):
    axes[i].scatter(X[feature], df[target], alpha=0.5)
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel(target)
    axes[i].set_title(f'{feature} vs {target}')

# Remove unused subplots
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                          Age  Academic Pressure  Work Pressure      CGPA  \
# Age                 1.000000          -0.075871       0.002018  0.005167
# Academic Pressure  -0.075871           1.000000      -0.022236 -0.022325
# Work Pressure       0.002018          -0.022236       1.000000 -0.050919
# CGPA                0.005167          -0.022325      -0.050919  1.000000
# Study Satisfaction  0.009131          -0.110903      -0.021154 -0.044227
# Job Satisfaction   -0.000428          -0.024949       0.770652 -0.053656
# Work/Study Hours   -0.032775           0.096291      -0.005474  0.002613
# Depression         -0.226738           0.474805      -0.003345  0.022164
#
#                     Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# Age                           0.009131         -0.000428         -0.032775
# Academic Pressure            -0.110903         -0.024949          0.096291
# Work Pressure                -0.021154          0.770652         -0.005474
# ...

# %%
x=df.drop(['Depression'],axis=1)

print(x)
y = df['Depression']
print(y)
# Out:
#        Gender  Age           City Profession  Academic Pressure  \
# 0        Male   33  Visakhapatnam    Student                  5
# 1      Female   24      Bangalore    Student                  2
# 2        Male   31       Srinagar    Student                  3
# 3      Female   28       Varanasi    Student                  3
# 4      Female   25         Jaipur    Student                  4
# ...       ...  ...            ...        ...                ...
# 27865  Female   27          Surat    Student                  5
# 27866    Male   27       Ludhiana    Student                  2
# 27867    Male   31      Faridabad    Student                  3
# 27868  Female   18       Ludhiana    Student                  5
# 27869    Male   27          Patna    Student                  4
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0                  0  8.97                   2                 0
# ...

# %%
x= pd.get_dummies(x, drop_first=True)
print(x)
# Out:
#        Age  Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 0       33                  5              0  8.97                   2
# 1       24                  2              0  5.90                   5
# 2       31                  3              0  7.03                   5
# 3       28                  3              0  5.59                   2
# 4       25                  4              0  8.13                   3
# ...    ...                ...            ...   ...                 ...
# 27865   27                  5              0  5.75                   5
# 27866   27                  2              0  9.40                   3
# 27867   31                  3              0  6.61                   4
# 27868   18                  5              0  6.88                   2
# 27869   27                  4              0  9.24                   1
#
#        Job Satisfaction  Work/Study Hours  Gender_Male  \
# 0                     0                 3         True
# ...

# %%
counts = df['Depression'].value_counts()

print("No Depression:", counts[0])
print("Depression:", counts[1])
# Out:
# No Depression: 11562
# Depression: 16308

# %%
counts = df['Depression'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
plt.title('Depression Distribution')
plt.show()

# %%
counts = df['Depression'].value_counts()

labels = ['No Depression', 'Depression']

plt.figure(figsize=(6,6))
plt.pie(counts, labels=labels, autopct='%1.1f%%')
plt.title('Depression Distribution')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.40, train_size=0.60, random_state = 42)

# %% [markdown]
# # ***Logistic Regression***

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Define the target variable (y) and the feature variables (X).
X = df.drop(['Depression'], axis=1)
y = df['Depression']

# %%
x
# Out:
#        Age  Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 0       33                  5              0  8.97                   2
# 1       24                  2              0  5.90                   5
# 2       31                  3              0  7.03                   5
# 3       28                  3              0  5.59                   2
# 4       25                  4              0  8.13                   3
# ...    ...                ...            ...   ...                 ...
# 27865   27                  5              0  5.75                   5
# 27866   27                  2              0  9.40                   3
# 27867   31                  3              0  6.61                   4
# 27868   18                  5              0  6.88                   2
# 27869   27                  4              0  9.24                   1
#
#        Job Satisfaction  Work/Study Hours  Gender_Male  \
# 0                     0                 3         True
# ...

# %%
y
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 27865    0
# 27866    0
# 27867    0
# 27868    1
# 27869    1
# Name: Depression, Length: 27870, dtype: int64

# %%
from sklearn.metrics import confusion_matrix

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 0])

# %%
y_pred = model.predict(x_test)
y_prob = model.predict_proba(x_test)[:,1]

# %%
Logistic = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
Logistic
# Out:
#        Predicted  Actual
# 10075          1       1
# 16055          1       1
# 4322           1       1
# 7469           1       1
# 7924           0       0
# ...          ...     ...
# 12228          0       0
# 11066          0       0
# 8262           1       1
# 1037           1       1
# 26310          0       0
#
# [11148 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8443667025475422

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81      4744
#            1       0.84      0.89      0.87      6404
#
#     accuracy                           0.84     11148
#    macro avg       0.84      0.84      0.84     11148
# weighted avg       0.84      0.84      0.84     11148

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[3692 1052]
#  [ 683 5721]]

# %%
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Depression", "Depression"],
    yticklabels=["No Depression", "Depression"]
)

plt.title('Confusion Matrix – Depression Prediction')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label='AUC = %0.2f' % roc_auc)
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Depression Prediction')
plt.legend()
plt.show()

print("ROC-AUC Score:", roc_auc)
# Out:
# ROC-AUC Score: 0.919403009343865

# %% [markdown]
# # ***KNN Classifier***

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier(n_neighbors=20)

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %%
knn = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
knn
# Out:
#        Predicted  Actual
# 10075          1       1
# 16055          0       1
# 4322           1       1
# 7469           1       1
# 7924           0       0
# ...          ...     ...
# 12228          1       0
# 11066          0       0
# 8262           1       1
# 1037           1       1
# 26310          0       0
#
# [11148 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8035522066738429

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[3436, 1308],
#        [ 882, 5522]])

# %%
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Depression", "Depression"],
    yticklabels=["No Depression", "Depression"]
)

plt.title('Confusion Matrix – Depression Prediction')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
from sklearn.metrics import classification_report
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76      4744
#            1       0.81      0.86      0.83      6404
#
#     accuracy                           0.80     11148
#    macro avg       0.80      0.79      0.80     11148
# weighted avg       0.80      0.80      0.80     11148

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label='AUC = %0.2f' % roc_auc)
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Depression Prediction')
plt.legend()
plt.show()

print("ROC-AUC Score:", roc_auc)
# Out:
# ROC-AUC Score: 0.919403009343865

# %% [markdown]
# # ***Svm Classifier***

# %%
from sklearn.svm import SVC

# %%
model = SVC(kernel='linear')

# %%
model.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 0])

# %%
svm = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
svm
# Out:
#        Predicted  Actual
# 10075          1       1
# 16055          1       1
# 4322           1       1
# 7469           1       1
# 7924           0       0
# ...          ...     ...
# 12228          0       0
# 11066          0       0
# 8262           1       1
# 1037           1       1
# 26310          0       0
#
# [11148 rows x 2 columns]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8455328310010765

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[3697, 1047],
#        [ 675, 5729]])

# %%
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.81      4744
#            1       0.85      0.89      0.87      6404
#
#     accuracy                           0.85     11148
#    macro avg       0.85      0.84      0.84     11148
# weighted avg       0.85      0.85      0.84     11148

# %%
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Depression", "Depression"],
    yticklabels=["No Depression", "Depression"]
)

plt.title('Confusion Matrix – Depression Prediction')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label='AUC = %0.2f' % roc_auc)
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Depression Prediction')
plt.legend()
plt.show()

print("ROC-AUC Score:", roc_auc)
# Out:
# ROC-AUC Score: 0.919403009343865

# %% [markdown]
# # ***Desion Tree Classifier***

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 1, 0, ..., 1, 1, 0])

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
dt
# Out:
#        Predicted  Actual
# 10075          1       1
# 16055          1       1
# 4322           0       1
# 7469           1       1
# 7924           0       0
# ...          ...     ...
# 12228          0       0
# 11066          0       0
# 8262           1       1
# 1037           1       1
# 26310          0       0
#
# [11148 rows x 2 columns]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7734122712594187

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[3425, 1319],
#        [1207, 5197]])

# %%
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73      4744
#            1       0.80      0.81      0.80      6404
#
#     accuracy                           0.77     11148
#    macro avg       0.77      0.77      0.77     11148
# weighted avg       0.77      0.77      0.77     11148

# %%
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Depression", "Depression"],
    yticklabels=["No Depression", "Depression"]
)

plt.title('Confusion Matrix – Depression Prediction')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label='AUC = %0.2f' % roc_auc)
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Depression Prediction')
plt.legend()
plt.show()

print("ROC-AUC Score:", roc_auc)
# Out:
# ROC-AUC Score: 0.919403009343865

# %% [markdown]
# # ***Random Forest***

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 1, 0, ..., 1, 1, 0])

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
dt
# Out:
#        Predicted  Actual
# 10075          1       1
# 16055          1       1
# 4322           0       1
# 7469           1       1
# 7924           0       0
# ...          ...     ...
# 12228          0       0
# 11066          0       0
# 8262           1       1
# 1037           1       1
# 26310          0       0
#
# [11148 rows x 2 columns]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8396124865446717

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[3669, 1075],
#        [ 713, 5691]])

# %%
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.77      0.80      4744
#            1       0.84      0.89      0.86      6404
#
#     accuracy                           0.84     11148
#    macro avg       0.84      0.83      0.83     11148
# weighted avg       0.84      0.84      0.84     11148

# %%
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Depression", "Depression"],
    yticklabels=["No Depression", "Depression"]
)

plt.title('Confusion Matrix – Depression Prediction')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label='AUC = %0.2f' % roc_auc)
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Depression Prediction')
plt.legend()
plt.show()

print("ROC-AUC Score:", roc_auc)
# Out:
# ROC-AUC Score: 0.919403009343865

# %% [markdown]
# # ***Bagging***

# %%
from sklearn.ensemble import BaggingClassifier

# %%
model = BaggingClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# BaggingClassifier()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 1, 0, ..., 1, 0, 0])

# %%
dt = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
dt
# Out:
#        Predicted  Actual
# 10075          1       1
# 16055          1       1
# 4322           0       1
# 7469           1       1
# 7924           0       0
# ...          ...     ...
# 12228          0       0
# 11066          0       0
# 8262           1       1
# 1037           0       1
# 26310          0       0
#
# [11148 rows x 2 columns]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8189809831359885

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[3745,  999],
#        [1019, 5385]])

# %%
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79      4744
#            1       0.84      0.84      0.84      6404
#
#     accuracy                           0.82     11148
#    macro avg       0.81      0.82      0.81     11148
# weighted avg       0.82      0.82      0.82     11148

# %%
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Depression", "Depression"],
    yticklabels=["No Depression", "Depression"]
)

plt.title('Confusion Matrix – Depression Prediction')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label='AUC = %0.2f' % roc_auc)
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Depression Prediction')
plt.legend()
plt.show()

print("ROC-AUC Score:", roc_auc)
# Out:
# ROC-AUC Score: 0.919403009343865

# %% [markdown]
# # ***Boosting Classifier***

# %% [markdown]
# # ***Ada Boost***

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
model = AdaBoostClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 0])

# %%
dt_ada = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
dt_ada
# Out:
#        Predicted  Actual
# 10075          1       1
# 16055          1       1
# 4322           1       1
# 7469           1       1
# 7924           0       0
# ...          ...     ...
# 12228          0       0
# 11066          0       0
# 8262           1       1
# 1037           1       1
# 26310          0       0
#
# [11148 rows x 2 columns]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.84167563688554

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[3707, 1037],
#        [ 728, 5676]])

# %%
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81      4744
#            1       0.85      0.89      0.87      6404
#
#     accuracy                           0.84     11148
#    macro avg       0.84      0.83      0.84     11148
# weighted avg       0.84      0.84      0.84     11148

# %%
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Depression", "Depression"],
    yticklabels=["No Depression", "Depression"]
)

plt.title('Confusion Matrix – Depression Prediction')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label='AUC = %0.2f' % roc_auc)
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Depression Prediction')
plt.legend()
plt.show()

print("ROC-AUC Score:", roc_auc)
# Out:
# ROC-AUC Score: 0.919403009343865

# %% [markdown]
# # ***Gradient Boost***

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
model = GradientBoostingClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 1, 0, ..., 1, 1, 0])

# %%
dt_gb = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
dt_gb
# Out:
#        Predicted  Actual
# 10075          1       1
# 16055          1       1
# 4322           0       1
# 7469           1       1
# 7924           0       0
# ...          ...     ...
# 12228          0       0
# 11066          0       0
# 8262           1       1
# 1037           1       1
# 26310          0       0
#
# [11148 rows x 2 columns]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8453534266236096

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[3693, 1051],
#        [ 673, 5731]])

# %%
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.81      4744
#            1       0.85      0.89      0.87      6404
#
#     accuracy                           0.85     11148
#    macro avg       0.85      0.84      0.84     11148
# weighted avg       0.85      0.85      0.84     11148

# %%
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Depression", "Depression"],
    yticklabels=["No Depression", "Depression"]
)

plt.title('Confusion Matrix – Depression Prediction')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label='AUC = %0.2f' % roc_auc)
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Depression Prediction')
plt.legend()
plt.show()

print("ROC-AUC Score:", roc_auc)
# Out:
# ROC-AUC Score: 0.919403009343865

# %% [markdown]
# # ***XG Boost***

# %%
from xgboost import XGBClassifier

# %%
model = XGBClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 1, 0, ..., 1, 1, 0])

# %%
dt_xgb = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
dt_xgb
# Out:
#        Predicted  Actual
# 10075          1       1
# 16055          1       1
# 4322           0       1
# 7469           1       1
# 7924           0       0
# ...          ...     ...
# 12228          0       0
# 11066          0       0
# 8262           1       1
# 1037           1       1
# 26310          0       0
#
# [11148 rows x 2 columns]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8379978471474704

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[3702, 1042],
#        [ 764, 5640]])

# %%
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.78      0.80      4744
#            1       0.84      0.88      0.86      6404
#
#     accuracy                           0.84     11148
#    macro avg       0.84      0.83      0.83     11148
# weighted avg       0.84      0.84      0.84     11148

# %%
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Depression", "Depression"],
    yticklabels=["No Depression", "Depression"]
)

plt.title('Confusion Matrix – Depression Prediction')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label='AUC = %0.2f' % roc_auc)
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Depression Prediction')
plt.legend()
plt.show()

print("ROC-AUC Score:", roc_auc)
# Out:
# ROC-AUC Score: 0.919403009343865

# %% [markdown]
# # ***Navie Bayes Classifier***

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model = GaussianNB()

# %%
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
dt_nb = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
dt_nb
# Out:
#        Predicted  Actual
# 10075          0       1
# 16055          0       1
# 4322           0       1
# 7469           0       1
# 7924           0       0
# ...          ...     ...
# 12228          0       0
# 11066          0       0
# 8262           0       1
# 1037           0       1
# 26310          0       0
#
# [11148 rows x 2 columns]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.4425905992106207

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[4734,   10],
#        [6204,  200]])

# %%
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.43      1.00      0.60      4744
#            1       0.95      0.03      0.06      6404
#
#     accuracy                           0.44     11148
#    macro avg       0.69      0.51      0.33     11148
# weighted avg       0.73      0.44      0.29     11148

# %%
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Depression", "Depression"],
    yticklabels=["No Depression", "Depression"]
)

plt.title('Confusion Matrix – Depression Prediction')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label='AUC = %0.2f' % roc_auc)
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Depression Prediction')
plt.legend()
plt.show()

print("ROC-AUC Score:", roc_auc)
# Out:
# ROC-AUC Score: 0.919403009343865

# %% [markdown]
# # ***Multi-Layer Perceptron (MLP)***

# %%
from sklearn.neural_network import MLPClassifier

# %%
model = MLPClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# MLPClassifier()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 0])

# %%
dt_mlp = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
dt_mlp
# Out:
#        Predicted  Actual
# 10075          1       1
# 16055          1       1
# 4322           1       1
# 7469           1       1
# 7924           0       0
# ...          ...     ...
# 12228          0       0
# 11066          0       0
# 8262           1       1
# 1037           1       1
# 26310          0       0
#
# [11148 rows x 2 columns]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8292967348403301

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[3667, 1077],
#        [ 826, 5578]])

# %%
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.77      0.79      4744
#            1       0.84      0.87      0.85      6404
#
#     accuracy                           0.83     11148
#    macro avg       0.83      0.82      0.82     11148
# weighted avg       0.83      0.83      0.83     11148

# %%
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Depression", "Depression"],
    yticklabels=["No Depression", "Depression"]
)

plt.title('Confusion Matrix – Depression Prediction')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label='AUC = %0.2f' % roc_auc)
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Depression Prediction')
plt.legend()
plt.show()

print("ROC-AUC Score:", roc_auc)
# Out:
# ROC-AUC Score: 0.919403009343865

# %% [markdown]
# # ***Stochastic Gradient Descent (SGD) Classifier***

# %%
from sklearn.linear_model import SGDClassifier

# %%
model = SGDClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# SGDClassifier()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 0, 0, ..., 1, 1, 0])

# %%
dt_sgd = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
dt_sgd
# Out:
#        Predicted  Actual
# 10075          1       1
# 16055          0       1
# 4322           0       1
# 7469           1       1
# 7924           0       0
# ...          ...     ...
# 12228          0       0
# 11066          0       0
# 8262           1       1
# 1037           1       1
# 26310          0       0
#
# [11148 rows x 2 columns]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.809562253318981

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[4321,  423],
#        [1700, 4704]])

# %%
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.91      0.80      4744
#            1       0.92      0.73      0.82      6404
#
#     accuracy                           0.81     11148
#    macro avg       0.82      0.82      0.81     11148
# weighted avg       0.83      0.81      0.81     11148

# %%
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Depression", "Depression"],
    yticklabels=["No Depression", "Depression"]
)

plt.title('Confusion Matrix – Depression Prediction')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label='AUC = %0.2f' % roc_auc)
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Depression Prediction')
plt.legend()
plt.show()

print("ROC-AUC Score:", roc_auc)
# Out:
# ROC-AUC Score: 0.919403009343865

# %% [markdown]
# # ***CatBoost Classifier***

# %%
 # !pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 9.8 MB/s eta 0:00:00
# ...

# %%
from catboost import CatBoostClassifier

# %%
model = CatBoostClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# Learning rate set to 0.034299
# 0:	learn: 0.6681292	total: 53.7ms	remaining: 53.6s
# 1:	learn: 0.6443130	total: 61.6ms	remaining: 30.8s
# 2:	learn: 0.6224896	total: 67.1ms	remaining: 22.3s
# 3:	learn: 0.6027762	total: 74.1ms	remaining: 18.4s
# 4:	learn: 0.5856225	total: 80.8ms	remaining: 16.1s
# 5:	learn: 0.5684075	total: 88ms	remaining: 14.6s
# 6:	learn: 0.5528259	total: 94.5ms	remaining: 13.4s
# 7:	learn: 0.5404987	total: 101ms	remaining: 12.5s
# 8:	learn: 0.5277345	total: 107ms	remaining: 11.8s
# 9:	learn: 0.5171345	total: 113ms	remaining: 11.2s
# 10:	learn: 0.5075066	total: 119ms	remaining: 10.7s
# 11:	learn: 0.4975475	total: 125ms	remaining: 10.3s
# 12:	learn: 0.4889555	total: 131ms	remaining: 9.96s
# 13:	learn: 0.4803333	total: 137ms	remaining: 9.67s
# 14:	learn: 0.4725196	total: 143ms	remaining: 9.39s
# 15:	learn: 0.4657438	total: 150ms	remaining: 9.2s
# 16:	learn: 0.4587096	total: 156ms	remaining: 8.99s
# 17:	learn: 0.4523584	total: 161ms	remaining: 8.78s
# ...

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 1, 0, ..., 1, 1, 0])

# %%
dt_cb = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
dt_cb
# Out:
#        Predicted  Actual
# 10075          1       1
# 16055          1       1
# 4322           0       1
# 7469           1       1
# 7924           0       0
# ...          ...     ...
# 12228          0       0
# 11066          0       0
# 8262           1       1
# 1037           1       1
# 26310          0       0
#
# [11148 rows x 2 columns]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8439181916038752

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[3703, 1041],
#        [ 699, 5705]])

# %%
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81      4744
#            1       0.85      0.89      0.87      6404
#
#     accuracy                           0.84     11148
#    macro avg       0.84      0.84      0.84     11148
# weighted avg       0.84      0.84      0.84     11148

# %%
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Depression", "Depression"],
    yticklabels=["No Depression", "Depression"]
)

plt.title('Confusion Matrix – Depression Prediction')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label='AUC = %0.2f' % roc_auc)
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Depression Prediction')
plt.legend()
plt.show()

print("ROC-AUC Score:", roc_auc)
# Out:
# ROC-AUC Score: 0.919403009343865

# %% [markdown]
# # ***LightGBM (Light Gradient Boosting Machine)***

# %%
# !pip install lightgbm

# %%
from lightgbm import LGBMClassifier

# %%
model = LGBMClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 9904, number of negative: 6818
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.014600 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 427
# [LightGBM] [Info] Number of data points in the train set: 16722, number of used features: 74
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.592274 -> initscore=0.373373
# [LightGBM] [Info] Start training from score 0.373373
# LGBMClassifier()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 1, 0, ..., 1, 1, 0])

# %%
dt_lgbm = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
dt_lgbm
# Out:
#        Predicted  Actual
# 10075          1       1
# 16055          1       1
# 4322           0       1
# 7469           1       1
# 7924           0       0
# ...          ...     ...
# 12228          0       0
# 11066          0       0
# 8262           1       1
# 1037           1       1
# 26310          0       0
#
# [11148 rows x 2 columns]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8441872981700753

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[3709, 1035],
#        [ 702, 5702]])

# %%
classification_rep = classification_report(y_test, y_pred)
print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81      4744
#            1       0.85      0.89      0.87      6404
#
#     accuracy                           0.84     11148
#    macro avg       0.84      0.84      0.84     11148
# weighted avg       0.84      0.84      0.84     11148

# %%
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Depression", "Depression"],
    yticklabels=["No Depression", "Depression"]
)

plt.title('Confusion Matrix – Depression Prediction')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label='AUC = %0.2f' % roc_auc)
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Depression Prediction')
plt.legend()
plt.show()

print("ROC-AUC Score:", roc_auc)
# Out:
# ROC-AUC Score: 0.919403009343865

# %% [markdown]
# # ***ANN***

# %%
import tensorflow as tf

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model= tf.keras.Sequential([
                            tf.keras.layers.Dense(10),
                            tf.keras.layers.Dense(5),
                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model   # optimizer can be SGD, Adam

model.compile(loss= tf.keras.losses.mae,
              optimizer= tf.keras.optimizers.Adam(),  #SGD
              metrics= ["mae"])

# STEP3: Fit the model

history= model.fit(x_train, y_train, epochs= 10, verbose=1)
# Out:
# Epoch 1/10
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.4237 - mae: 0.4237
# Epoch 2/10
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.2541 - mae: 0.2541
# Epoch 3/10
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2376 - mae: 0.2376
# Epoch 4/10
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2334 - mae: 0.2334
# Epoch 5/10
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2329 - mae: 0.2329
# Epoch 6/10
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2311 - mae: 0.2311
# Epoch 7/10
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.2315 - mae: 0.2315
# Epoch 8/10
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2326 - mae: 0.2326
# Epoch 9/10
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2315 - mae: 0.2315
# Epoch 10/10
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2308 - mae: 0.2308

# %%
model.evaluate(x_test, y_test)
# Out:
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2333 - mae: 0.2333
# [0.23325859010219574, 0.23325859010219574]

# %%
model.summary();
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │         1,010 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,215 (12.56 KB)
#  Trainable params: 1,071 (4.18 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2,144 (8.38 KB)

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model1= tf.keras.Sequential([
                            tf.keras.layers.Dense(10, activation='relu'),
                            tf.keras.layers.Dense(1, activation='linear')
])

# STEP2: Compiling the model

model1.compile(
    loss=tf.keras.losses.MeanAbsoluteError(),
    optimizer=tf.keras.optimizers.SGD(),
    metrics=[
        tf.keras.metrics.MeanAbsoluteError(name="mae"),
        tf.keras.metrics.MeanSquaredError(name="mse"),
        tf.keras.metrics.MeanAbsolutePercentageError(name="mape")
    ]
)


# STEP1: Fit the model

history= model1.fit(x_train, y_train, epochs= 200, verbose=0)

# %%
model1.evaluate(x_test, y_test)
# Out:
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2290 - mae: 0.2290 - mape: 162016704.0000 - mse: 0.1318
# [0.2289816290140152, 0.2289816290140152, 0.13180291652679443, 162016704.0]

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model2= tf.keras.Sequential([
                            tf.keras.layers.Dense(10, activation='relu'),
                            tf.keras.layers.Dense(7, activation='relu'),
                            tf.keras.layers.Dense(5, activation='relu'),
                            tf.keras.layers.Dense(3, activation='relu'),
                            tf.keras.layers.Dense(1, activation='linear')
])

# STEP2: Compiling the model

model2.compile(
    loss=tf.keras.losses.mae,
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[ tf.keras.metrics.MeanAbsoluteError(name="mae")
    ]
)

# STEP1: Fit the model

history= model2.fit(x_train, y_train, epochs= 500)
# Out:
# Epoch 1/500
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3433 - mae: 0.3433
# Epoch 2/500
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2191 - mae: 0.2191
# Epoch 3/500
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2006 - mae: 0.2006
# Epoch 4/500
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1914 - mae: 0.1914
# Epoch 5/500
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1848 - mae: 0.1848
# Epoch 6/500
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1798 - mae: 0.1798
# Epoch 7/500
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1750 - mae: 0.1750
# Epoch 8/500
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1703 - mae: 0.1703
# Epoch 9/500
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1667 - mae: 0.1667
# Epoch 10/500
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1661 - mae: 0.1661
# Epoch 11/500
# 523/523 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1623 - mae: 0.1623
# Epoch 12/500
# ...

# %%
# Convert training history to DataFrame
history_df = pd.DataFrame(history.history)

# Plot all metrics
history_df.plot(figsize=(10, 6))

# Add title and labels
plt.title("Training Metrics Over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Value")
plt.grid(True)
plt.show()

# %%
model2.evaluate(x_test, y_test)
# Out:
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1625 - mae: 0.1625
# [0.16245639324188232, 0.16245639324188232]

# %%
model.summary();
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │         1,010 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,215 (12.56 KB)
#  Trainable params: 1,071 (4.18 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2,144 (8.38 KB)

# %%
def evaluate_model(model, model_name, x_test=None, y_test=None):
    """
    Evaluates a trained model on training or test data.
    """
    from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
    import numpy as np

    # Use test data if provided, otherwise training data
    if x_test is None or y_test is None:
        X, Y = x_train, y_train
    else:
        X, Y = x_test, y_test

    # Predictions
    y_pred = model.predict(X).flatten()

    # Metrics
    mae = mean_absolute_error(Y, y_pred)
    mse = mean_squared_error(Y, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(Y, y_pred)

    # Print results
    print(f"\nModel: {model_name}")
    print(f"MAE: {mae:.4f}, RMSE: {rmse:.4f}, R²: {r2:.4f}")

    # Store results in dictionary for comparison later
    results_ann.append({
        'Model': model_name,
        'MAE': mae,
        'RMSE': rmse,
        'R2 Score': r2
    })

# %% [markdown]
# # ***Different Train test splits (80-20,75-25,60-40)***

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from lightgbm import LGBMClassifier
import xgboost as xgb
import pandas as pd

# %%
# ========== Models ==========
def get_models():
    return {
        "Logistic Regression": LogisticRegression(max_iter=1000),
        "KNN": KNeighborsClassifier(),
        "SVC": SVC(probability=True),
        "Decision Tree": DecisionTreeClassifier(random_state=42),
        "Random Forest": RandomForestClassifier(random_state=42),
        "Bagging": BaggingClassifier(random_state=42),
        "AdaBoost": AdaBoostClassifier(random_state=42),
        "Gradient Boosting": GradientBoostingClassifier(random_state=42),
        "XGBoost": xgb.XGBClassifier(eval_metric='logloss', random_state=42),
        "Naive Bayes": GaussianNB(),
        "MLP": MLPClassifier(hidden_layer_sizes=(64,32), max_iter=500, random_state=42),
        "SGD": SGDClassifier(loss='log_loss', random_state=42),
        "LightGBM": LGBMClassifier(random_state=42),
        "CatBoost": CatBoostClassifier(verbose=0, random_state=42)
    }

# %%
# ========== Evaluation ==========
def evaluate_model(y_true, y_pred, y_prob):
    return {
        "Accuracy": accuracy_score(y_true, y_pred),
        "Precision": precision_score(y_true, y_pred),
        "Recall": recall_score(y_true, y_pred),
        "F1-Score": f1_score(y_true, y_pred),
        "ROC-AUC": roc_auc_score(y_true, y_prob)
    }

# %%
# ========== Run for different splits ==========
splits = [0.20, 0.25, 0.30,0.35]
all_results = []

for test_size in splits:
    X_train, X_test, y_train, y_test = train_test_split(
        x, y, test_size=test_size, random_state=42
    )

    models = get_models()

    for name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        # predict_proba is not available for all models (e.g., SGDClassifier with certain loss functions)
        if hasattr(model, "predict_proba"):
            y_prob = model.predict_proba(X_test)[:, 1]
        else:
            # For models without predict_proba, use dummy probabilities or handle as appropriate
            y_prob = [0.5] * len(y_test) # Placeholder

        metrics = evaluate_model(y_test, y_pred, y_prob)
        metrics["Model"] = name
        metrics["Train-Test Split"] = f"{int((1-test_size)*100)}-{int(test_size*100)}"
        all_results.append(metrics)

# Convert to DataFrame
results_df = pd.DataFrame(all_results)
results_df
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 13081, number of negative: 9215
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001246 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 428
# [LightGBM] [Info] Number of data points in the train set: 22296, number of used features: 74
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.586697 -> initscore=0.350328
# [LightGBM] [Info] Start training from score 0.350328
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 12295, number of negative: 8607
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001688 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# ...

# %%
# Convert results into DataFrame (run this once after your training loop)
results_df = pd.DataFrame(all_results)

# Show results separately for each test split
for split in results_df["Train-Test Split"].unique():
    split_df = results_df[results_df["Train-Test Split"] == split].drop(columns=["Train-Test Split"])
    print(f"\n===== Results for Split {split} =====\n")
    display(split_df)

    # Optional: quick bar chart for R² comparison
    split_df.plot(x="Model", y="ROC-AUC", kind="bar", title=f"ROC-AUC Scores ({split} Split)")
    plt.show()
# Out:
# ===== Results for Split 80-20 =====
#     Accuracy  Precision    Recall  F1-Score   ROC-AUC                Model
# 0   0.847147   0.850605  0.892780  0.871182  0.921427  Logistic Regression
# 1   0.791173   0.799419  0.853424  0.825540  0.851222                  KNN
# 2   0.842483   0.839549  0.899907  0.868681  0.919255                  SVC
# 3   0.773592   0.800919  0.810350  0.805607  0.766700        Decision Tree
# 4   0.839254   0.844517  0.885342  0.864448  0.913261        Random Forest
# 5   0.824184   0.847725  0.848776  0.848250  0.890413              Bagging
# 6   0.842483   0.851541  0.881624  0.866322  0.918209             AdaBoost
# 7   0.845533   0.848762  0.892160  0.869920  0.921032    Gradient Boosting
# 8   0.839792   0.847735  0.881624  0.864348  0.911296              XGBoost
# 9   0.420883   0.444444  0.001240  0.002472  0.816563          Naive Bayes
# 10  0.817905   0.826639  0.867369  0.846514  0.884915                  MLP
# ...

# %% [markdown]
# # ***ANN Variants***

# %%
# Model 1 - Deep ANN with ELU + Adam (Classification)

model1 = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='elu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(32, activation='elu'),
    tf.keras.layers.Dense(16, activation='elu'),
    tf.keras.layers.Dense(8, activation='elu'),
    tf.keras.layers.Dense(1, activation='sigmoid')  # classification output
])

# Compile
model1.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0008),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Train
history1 = model1.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    verbose=0
)

# Predict probabilities
y_prob1 = model1.predict(X_test).flatten()

# Convert to class labels
y_pred1 = (y_prob1 >= 0.5).astype(int)

# Evaluate
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

metrics1 = {
    "Accuracy": accuracy_score(y_test, y_pred1),
    "Precision": precision_score(y_test, y_pred1),
    "Recall": recall_score(y_test, y_pred1),
    "F1-Score": f1_score(y_test, y_pred1),
    "ROC-AUC": roc_auc_score(y_test, y_prob1)
}

metrics1["Model"] = "ANN - Deep ELU Adam"
metrics1
# Out:
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# {'Accuracy': 0.7980522808815992,
#  'Precision': 0.7948345439870863,
#  'Recall': 0.8756891339142806,
#  'F1-Score': 0.8333051277711965,
#  'ROC-AUC': np.float64(0.8558268281341379),
#  'Model': 'ANN - Deep ELU Adam'}

# %%
# Model 2 - Simple ANN with tanh + RMSprop (Classification)

model2 = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='tanh', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(16, activation='tanh'),
    tf.keras.layers.Dense(1, activation='sigmoid')  # classification output
])

# Compile
model2.compile(
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Train
history2 = model2.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    verbose=0
)

# Predict probabilities
y_prob2 = model2.predict(X_test).flatten()

# Convert to class labels
y_pred2 = (y_prob2 >= 0.5).astype(int)

# Evaluate
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

metrics2 = {
    "Accuracy": accuracy_score(y_test, y_pred2),
    "Precision": precision_score(y_test, y_pred2),
    "Recall": recall_score(y_test, y_pred2),
    "F1-Score": f1_score(y_test, y_pred2),
    "ROC-AUC": roc_auc_score(y_test, y_prob2)
}

metrics2["Model"] = "ANN - Simple tanh RMSprop"
metrics2
# Out:
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# {'Accuracy': 0.8320861096873399,
#  'Precision': 0.8456201214223764,
#  'Recall': 0.8669749244175707,
#  'F1-Score': 0.8561643835616438,
#  'ROC-AUC': np.float64(0.909547789735802),
#  'Model': 'ANN - Simple tanh RMSprop'}

# %%
# Model 3 - Simple ANN with SELU + Nadam (Classification)

model3 = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='selu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(16, activation='selu'),
    tf.keras.layers.Dense(1, activation='sigmoid')  # classification output
])

# Compile
model3.compile(
    optimizer=tf.keras.optimizers.Nadam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Train
history3 = model3.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    verbose=0
)

# Predict probabilities
y_prob3 = model3.predict(X_test).flatten()

# Convert to class labels
y_pred3 = (y_prob3 >= 0.5).astype(int)

# Evaluate
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

metrics3 = {
    "Accuracy": accuracy_score(y_test, y_pred3),
    "Precision": precision_score(y_test, y_pred3),
    "Recall": recall_score(y_test, y_pred3),
    "F1-Score": f1_score(y_test, y_pred3),
    "ROC-AUC": roc_auc_score(y_test, y_prob3)
}

metrics3["Model"] = "ANN - Simple SELU Nadam"
metrics3
# Out:
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# {'Accuracy': 0.8359815479241415,
#  'Precision': 0.843787386771492,
#  'Recall': 0.8780010670460608,
#  'F1-Score': 0.8605542966707338,
#  'ROC-AUC': np.float64(0.9065131300207159),
#  'Model': 'ANN - Simple SELU Nadam'}

# %%
# Model 4 - Complex ANN with Dropout + ReLU + Adam (Classification)

model4 = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')  # classification output
])

# Compile
model4.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Train
history4 = model4.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=150,
    batch_size=32,
    verbose=0
)

# Predict probabilities
y_prob4 = model4.predict(X_test).flatten()

# Convert to class labels
y_pred4 = (y_prob4 >= 0.5).astype(int)

# Evaluate
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

metrics4 = {
    "Accuracy": accuracy_score(y_test, y_pred4),
    "Precision": precision_score(y_test, y_pred4),
    "Recall": recall_score(y_test, y_pred4),
    "F1-Score": f1_score(y_test, y_pred4),
    "ROC-AUC": roc_auc_score(y_test, y_prob4)
}

metrics4["Model"] = "ANN - Complex ReLU Dropout Adam"
metrics4
# Out:
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# {'Accuracy': 0.8357765248590466,
#  'Precision': 0.8438515478022918,
#  'Recall': 0.87746754401565,
#  'F1-Score': 0.8603312990409765,
#  'ROC-AUC': np.float64(0.89595767211799),
#  'Model': 'ANN - Complex ReLU Dropout Adam'}

# %%
# Model 5 - Large ANN with Dropout + SELU + RMSprop (Classification)

model5 = tf.keras.Sequential([
    tf.keras.layers.Dense(256, activation='selu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(128, activation='selu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(64, activation='selu'),
    tf.keras.layers.Dense(1, activation='sigmoid')  # classification output
])

# Compile
model5.compile(
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Train
history5 = model5.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=200,
    batch_size=32,
    verbose=0
)

# Predict probabilities
y_prob5 = model5.predict(X_test).flatten()

# Convert to class labels
y_pred5 = (y_prob5 >= 0.5).astype(int)

# Evaluate
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

metrics5 = {
    "Accuracy": accuracy_score(y_test, y_pred5),
    "Precision": precision_score(y_test, y_pred5),
    "Recall": recall_score(y_test, y_pred5),
    "F1-Score": f1_score(y_test, y_pred5),
    "ROC-AUC": roc_auc_score(y_test, y_prob5)
}

metrics5["Model"] = "ANN - Large SELU Dropout RMSprop"
metrics5
# Out:
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# {'Accuracy': 0.8421322398769862,
#  'Precision': 0.85059247810407,
#  'Recall': 0.8808465232082519,
#  'F1-Score': 0.8654551808492049,
#  'ROC-AUC': np.float64(0.9155766946673003),
#  'Model': 'ANN - Large SELU Dropout RMSprop'}

# %%
# Create a DataFrame to store the results
results_df = pd.DataFrame(all_results)

print("\n===== Model Comparison (Sorted by Accuracy) =====\n")

# Sort by Accuracy (highest first)
results_df_sorted = results_df.sort_values(by="Accuracy", ascending=False)

display(results_df_sorted)
# Out:
# ===== Model Comparison (Sorted by Accuracy) =====
#     Accuracy  Precision    Recall  F1-Score   ROC-AUC                Model  \
# 13  0.850736   0.854185  0.894949  0.874092  0.921492             CatBoost
# 39  0.849061   0.853784  0.892216  0.872577  0.920800                  SGD
# 40  0.848463   0.852385  0.893042  0.872240  0.919849             LightGBM
# 28  0.847985   0.851575  0.893248  0.871914  0.920844  Logistic Regression
# 14  0.847445   0.848865  0.894343  0.871011  0.921132  Logistic Regression
# 41  0.847387   0.851567  0.892009  0.871319  0.919874             CatBoost
# 42  0.847360   0.849391  0.893651  0.870959  0.920533  Logistic Regression
# 12  0.847327   0.851479  0.891850  0.871197  0.920862             LightGBM
# 21  0.847158   0.846660  0.897084  0.871143  0.920754    Gradient Boosting
# 0   0.847147   0.850605  0.892780  0.871182  0.921427  Logistic Regression
# 35  0.846908   0.848972  0.894900  0.871331  0.920966    Gradient Boosting
# ...

# %%
# Melt the DataFrame for easier plotting
results_melted = results_df.melt(id_vars=["Model", "Train-Test Split"],
                                 var_name="Metric",
                                 value_name="Score")

# Metrics to plot
metrics_to_plot = ["Accuracy", "Precision", "Recall", "F1-Score", "ROC-AUC"]

fig, axes = plt.subplots(3, 2, figsize=(18, 12))
axes = axes.flatten()

for i, metric in enumerate(metrics_to_plot):
    sns.barplot(
        x="Model",
        y="Score",
        hue="Train-Test Split",
        data=results_melted[results_melted["Metric"] == metric],
        ax=axes[i]
    )
    axes[i].set_title(f"{metric} Comparison")
    axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45, ha='right')
    axes[i].legend(title="Train-Test Split")
    axes[i].grid(axis='y')

# Remove extra empty subplot
fig.delaxes(axes[-1])

plt.tight_layout()
plt.show()

# %%
# Find the row with the highest Accuracy
best_model_row = results_df.loc[results_df["Accuracy"].idxmax()]

# Display the best model's results
print("\n===== Best Model Performance (Based on Accuracy) =====\n")
display(best_model_row)
# Out:
# ===== Best Model Performance (Based on Accuracy) =====
# Accuracy            0.850736
# Precision           0.854185
# Recall              0.894949
# F1-Score            0.874092
# ROC-AUC             0.921492
# Model               CatBoost
# Train-Test Split       80-20
# Name: 13, dtype: object

# %%
# Filter the results for the best performing model (based on Accuracy)
best_model_name = results_df.loc[results_df["Accuracy"].idxmax()]["Model"]
best_model_results = results_df[results_df["Model"] == best_model_name]

# Melt the filtered DataFrame for easier plotting
best_model_melted = best_model_results.melt(
    id_vars=["Model", "Train-Test Split"],
    var_name="Metric",
    value_name="Score"
)

# Metrics to plot
metrics_to_plot = ["Accuracy", "Precision", "Recall", "F1-Score", "ROC-AUC"]

fig, axes = plt.subplots(3, 2, figsize=(14, 10))
axes = axes.flatten()

for i, metric in enumerate(metrics_to_plot):
    sns.barplot(
        x="Train-Test Split",
        y="Score",
        data=best_model_melted[best_model_melted["Metric"] == metric],
        ax=axes[i]
    )
    axes[i].set_title(f"{metric} for {best_model_name}")
    axes[i].set_xlabel("Train-Test Split")
    axes[i].set_ylabel(metric)
    axes[i].grid(axis='y')

# Remove extra empty subplot
fig.delaxes(axes[-1])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Function to evaluate a classification model
def evaluate_model_classification(y_true, y_pred, y_prob):
    return {
        "Accuracy": accuracy_score(y_true, y_pred),
        "Precision": precision_score(y_true, y_pred),
        "Recall": recall_score(y_true, y_pred),
        "F1-Score": f1_score(y_true, y_pred),
        "ROC-AUC": roc_auc_score(y_true, y_prob)
    }

# Collect results
results = []

# Your ANN models
models_info = [
    ("ANN - Deep ELU Adam", model1, 100),
    ("ANN - Simple tanh RMSprop", model2, 100),
    ("ANN - Simple SELU Nadam", model3, 100),
    ("ANN - Complex ReLU Dropout Adam", model4, 150),
    ("ANN - Large SELU Dropout RMSprop", model5, 200)
]

for name, model, epochs in models_info:
    y_prob = model.predict(X_test).flatten()
    y_pred = (y_prob >= 0.5).astype(int)

    metrics = evaluate_model_classification(y_test, y_pred, y_prob)
    metrics["Model"] = name
    metrics["Split"] = "70-30"
    metrics["Epochs"] = epochs
    results.append(metrics)

# Create DataFrame
results_df = pd.DataFrame(results).round(4)

# Reorder columns
results_df = results_df[["Split", "Model", "Epochs", "Accuracy", "Precision", "Recall", "F1-Score", "ROC-AUC"]]

print("=== ANN Models Classification Evaluation Summary ===")
print(results_df)

# Save to CSV
results_df.to_csv("ANN_classification_results_summary.csv", index=False)
# Out:
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# === ANN Models Classification Evaluation Summary ===
#    Split                             Model  Epochs  Accuracy  Precision  \
# 0  70-30               ANN - Deep ELU Adam     100    0.7981     0.7948
# 1  70-30         ANN - Simple tanh RMSprop     100    0.8321     0.8456
# 2  70-30           ANN - Simple SELU Nadam     100    0.8360     0.8438
# 3  70-30   ANN - Complex ReLU Dropout Adam     150    0.8358     0.8439
# 4  70-30  ANN - Large SELU Dropout RMSprop     200    0.8421     0.8506
#
#    Recall  F1-Score  ROC-AUC
# 0  0.8757    0.8333   0.8558
# 1  0.8670    0.8562   0.9095
# 2  0.8780    0.8606   0.9065
# 3  0.8775    0.8603   0.8960
# 4  0.8808    0.8655   0.9156

# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Function to build ANN classification model
def build_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(64, activation='relu', input_shape=(x.shape[1],)), # Changed X to x
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')   # classification output
    ])
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

# Splits and epochs to test
splits = [(0.4, "60-40"), (0.3, "70-30"), (0.25, "75-25"), (0.2, "80-20"),(0.35,"65-35")]
epochs_list = [200, 300, 500]

results = []

for test_size, split_name in splits:
    X_train, X_test, y_train, y_test = train_test_split(
        x, y, test_size=test_size, random_state=42 # Changed X to x
    )

    for ep in epochs_list:
        model = build_model()
        history = model.fit(X_train, y_train,
                            epochs=ep,
                            verbose=0,
                            validation_split=0.1)

        # Predict probabilities
        y_prob = model.predict(X_test).flatten()
        y_pred = (y_prob >= 0.5).astype(int)

        # Metrics
        acc = accuracy_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)
        rec = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        auc = roc_auc_score(y_test, y_prob)

        results.append({
            "Split": split_name,
            "Architecture": "64-32-1",
            "Epochs": ep,
            "Accuracy": round(acc, 4),
            "Precision": round(prec, 4),
            "Recall": round(rec, 4),
            "F1-Score": round(f1, 4),
            "ROC-AUC": round(auc, 4)
        })

# Convert to DataFrame
results_df = pd.DataFrame(results)

print("=== Neural Network Classification Results (Adam Optimizer) ===")
print(results_df)
# Out:
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 262/262 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# === Neural Network Classification Results (Adam Optimizer) ===
#     Split Architecture  Epochs  Accuracy  Precision  Recall  F1-Score  ROC-AUC
# 0   60-40      64-32-1     200    0.7990     0.8106  0.8482    0.8290   0.8633
# 1   60-40      64-32-1     300    0.7753     0.7985  0.8143    0.8063   0.8313
# ...
